# %%
bt = get_backtest('59a8f3d31ca29d5746d456d5')
bt.create_position_tear_sheet()
# Out:
# 100% Time: 0:00:01|###########################################################|
# Top 10 long positions of all time    max
# AT-583                            98.05%
# RMK-23332                         90.70%
# WWY-8323                          89.99%
# K-4192                            58.52%
# WMT-8229                          49.57%
# BPT-1068                          46.62%
# NEE-2968                          43.43%
# UTHR-20306                        41.39%
# WES-8148                          38.75%
# THS-27406                         34.15%
# Empty DataFrame
# Columns: [max]
# Index: []
# Top 10 positions of all time    max
# AT-583                       98.05%
# RMK-23332                    90.70%
# WWY-8323                     89.99%
# K-4192                       58.52%
# WMT-8229                     49.57%
# BPT-1068                     46.62%
# NEE-2968                     43.43%
# UTHR-20306                   41.39%
# WES-8148                     38.75%
# ...

# %%
donut = bt.cumulative_performance

# %%
donut
# Out:
#                              cash_flow   ending_cash  ending_portfolio_value  \
# 2005-01-31 00:00:00+00:00     0.000000  10000.000000            10000.000000
# 2005-02-01 00:00:00+00:00 -9790.568788    209.431212            10179.631212
# 2005-02-02 00:00:00+00:00 -9790.568788    209.431212            10159.511212
# 2005-02-03 00:00:00+00:00 -9790.568788    209.431212            10192.031212
# 2005-02-04 00:00:00+00:00 -9790.568788    209.431212            10173.781212
# 2005-02-07 00:00:00+00:00 -9790.568788    209.431212            10138.551212
# 2005-02-08 00:00:00+00:00 -9790.568788    209.431212            10183.111212
# 2005-02-09 00:00:00+00:00 -9790.568788    209.431212            10219.751212
# 2005-02-10 00:00:00+00:00 -9790.568788    209.431212            10285.711212
# 2005-02-11 00:00:00+00:00 -9790.568788    209.431212            10235.361212
# 2005-02-14 00:00:00+00:00 -9790.568788    209.431212            10288.661212
# ...

# %%
bt.daily_performance
# Out:
#                              cash_flow   ending_cash  ending_portfolio_value  \
# 2005-01-31 00:00:00+00:00     0.000000  10000.000000            10000.000000
# 2005-02-01 00:00:00+00:00 -9790.568788    209.431212            10179.631212
# 2005-02-02 00:00:00+00:00     0.000000    209.431212            10159.511212
# 2005-02-03 00:00:00+00:00     0.000000    209.431212            10192.031212
# 2005-02-04 00:00:00+00:00     0.000000    209.431212            10173.781212
# 2005-02-07 00:00:00+00:00     0.000000    209.431212            10138.551212
# 2005-02-08 00:00:00+00:00     0.000000    209.431212            10183.111212
# 2005-02-09 00:00:00+00:00     0.000000    209.431212            10219.751212
# 2005-02-10 00:00:00+00:00     0.000000    209.431212            10285.711212
# 2005-02-11 00:00:00+00:00     0.000000    209.431212            10235.361212
# 2005-02-14 00:00:00+00:00     0.000000    209.431212            10288.661212
# ...

# %%
bt.orders
# Out:
#                            amount  commission              created_date  \
# 2005-02-01 00:00:00+00:00      22       0.022 2005-02-01 14:35:00+00:00
# 2005-02-01 00:00:00+00:00      20       0.020 2005-02-01 14:35:00+00:00
# 2005-02-01 00:00:00+00:00      13       0.013 2005-02-01 14:35:00+00:00
# 2005-02-01 00:00:00+00:00      84       0.084 2005-02-01 14:35:00+00:00
# 2005-02-01 00:00:00+00:00      29       0.029 2005-02-01 14:35:00+00:00
# 2005-02-01 00:00:00+00:00       6       0.006 2005-02-01 14:35:00+00:00
# 2005-02-01 00:00:00+00:00      13       0.013 2005-02-01 14:35:00+00:00
# 2005-02-01 00:00:00+00:00      42       0.042 2005-02-01 14:35:00+00:00
# 2005-05-02 00:00:00+00:00     -22       0.022 2005-05-02 13:35:00+00:00
# 2005-05-02 00:00:00+00:00     -29       0.029 2005-05-02 13:35:00+00:00
# 2005-05-02 00:00:00+00:00     103       0.103 2005-05-02 13:35:00+00:00
# 2005-05-02 00:00:00+00:00     -84       0.084 2005-05-02 13:35:00+00:00
# ...

# %%
bt.positions
# Out:
#                            amount  cost_basis  last_sale_price    sid
# 2005-02-01 00:00:00+00:00       6  127.191271          131.010    168
# 2005-02-01 00:00:00+00:00      20   53.863154           53.900   1068
# 2005-02-01 00:00:00+00:00      29   52.621023           53.380   3214
# 2005-02-01 00:00:00+00:00      42   16.024123           16.470   6390
# 2005-02-01 00:00:00+00:00      84   45.794516           46.960   8148
# 2005-02-01 00:00:00+00:00      13   34.881007           35.540  12350
# 2005-02-01 00:00:00+00:00      13   42.051494           42.140  22110
# 2005-02-01 00:00:00+00:00      22   41.103335           41.450  23179
# 2005-02-02 00:00:00+00:00       6  127.191271          130.610    168
# 2005-02-02 00:00:00+00:00      20   53.863154           55.430   1068
# 2005-02-02 00:00:00+00:00      29   52.621023           53.150   3214
# 2005-02-02 00:00:00+00:00      42   16.024123           16.570   6390
# ...

# %%
bt.risk
# Out:
#                                alpha  benchmark_period_return  \
# 2005-01-31 00:00:00+00:00        NaN                 0.008026
# 2005-02-01 00:00:00+00:00  40.058739                 0.015203
# 2005-02-02 00:00:00+00:00  -1.716380                 0.018952
# 2005-02-03 00:00:00+00:00   0.694126                 0.016393
# 2005-02-04 00:00:00+00:00   0.877146                 0.027148
# 2005-02-07 00:00:00+00:00   0.294880                 0.026468
# 2005-02-08 00:00:00+00:00   0.462709                 0.027412
# 2005-02-09 00:00:00+00:00   0.653119                 0.018527
# 2005-02-10 00:00:00+00:00   0.737969                 0.023050
# 2005-02-11 00:00:00+00:00   0.617575                 0.030651
# 2005-02-14 00:00:00+00:00   0.695676                 0.031161
# 2005-02-15 00:00:00+00:00   0.557433                 0.034664
# 2005-02-16 00:00:00+00:00   0.751048                 0.034664
# 2005-02-17 00:00:00+00:00   0.500938                 0.026893
# ...

# %%
print bt.start_date
print bt.end_date
# Out:
# 2005-01-31 00:00:00+00:00
# 2010-01-29 00:00:00+00:00
